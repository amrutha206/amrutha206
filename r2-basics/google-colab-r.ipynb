# %%
movie <- data.frame(
  genre = c( "SCI-FI","THRILLER","HORROR","ROMANCE","FANTASY","ACTION"),
  likes = c(25,15,10,10,15,25)
)

# %%
pie(
  movie$likes,
  labels = movie$genre,
  col = rainbow(6)
)
# Out:
# plot without title
