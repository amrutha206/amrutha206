# %% [markdown]
# <a href="https://colab.research.google.com/github/amrutha206/amrutha206/blob/main/r1-basics/google-colab-r.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
food_data <- data.frame(
  name = c("BRIYANI","SHAWARMA","DOSA","NAAN"),
  likes = c(40,20,25,15)
)

# %%
pie (food_data$likes,
     labels = food_data$name,
     col = rainbow(4))
# Out:
# plot without title
