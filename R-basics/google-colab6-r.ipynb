# %% [markdown]
# <a href="https://colab.research.google.com/github/amrutha206/amrutha206/blob/main/R-basics/google-colab6-r.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ads <- c(5,10,20,30,40,50)
sales <- c(120,220,380,520,610,650)

# %%
plot (ads,sales,
      pch = 16,
      col ="blue",
      main ="ads vs sales LOG reg",
      xlab = "ads",
      ylab= "phones sales"
      )
# Out:
# Plot with title “ads vs sales LOG reg”

# %%
model_LOG <- lm(sales~log(ads))
summary(model_LOG)
# Out:
# Call:
# lm(formula = sales ~ log(ads))
#
# Residuals:
#       1       2       3       4       5       6
#  35.109 -32.076 -39.261   2.942  23.554   9.733
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -303.30      52.37  -5.791 0.004420 **
# log(ads)      241.20      16.94  14.237 0.000141 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 33.4 on 4 degrees of freedom
# Multiple R-squared:  0.9806,	Adjusted R-squared:  0.9758
# F-statistic: 202.7 on 1 and 4 DF,  p-value: 0.0001413

# %%
plot (ads,sales,
      pch = 16,
      col ="brown",
      main ="log reg",

      )

curve(predict(model_LOG,data.frame(ads=x)),
                                      ad =TRUE,
                                      col = "blue",
                                      lwd =2)
# Out:
# Plot with title “log reg”

# %%
  plot(ads,high_sales,
     pch = 16,
     col ="blue",
     xlab ="ads",
     ylab = "high sales(0/1)",
                   main ="logistic regression curve")

curve (predict(model_logistic, data.frame(ads=x),
                                           type = "response"),
                                add = TRUE,
                                col = "red",
                                lwd =2)
# Out:
# Plot with title “logistic regression curve”
