# %% [markdown]
# <a href="https://colab.research.google.com/github/amrutha206/amrutha206/blob/main/R-basics/google-colab6-r.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LOGISTIC REGRESSION

# %%
ads <- c(5,10,20,30,40,50)
sales <- c(120,220,380,520,610,650)

# %%
high_sales <- ifelse (sales > 500,1,0)

# %%
data <- data.frame(ads,sales,high_sales)
data
# Out:
#   ads sales high_sales
# 1  5  120   0
# 2 10  220   0
# 3 20  380   0
# 4 30  520   1
# 5 40  610   1
# 6 50  650   1

# %%
model_logistic <- glm(high_sales ~ads, data =data, family = binomial())
summary(model_logistic)
# Out:
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Call:
# glm(formula = high_sales ~ ads, family = binomial(), data = data)
#
# Coefficients:
#               Estimate Std. Error z value Pr(>|z|)
# (Intercept)   -113.597 187683.874  -0.001        1
# ads              4.544   7356.136   0.001        1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 8.3178e+00  on 5  degrees of freedom
# Residual deviance: 5.4388e-10  on 4  degrees of freedom
# AIC: 4
#
# Number of Fisher Scoring iterations: 24

# %%
ifelse(predict(model_logistic, data.frame(ads=35),
                                          type ="response")>0.5,"YES","NO")
# Out:
#     1
# "YES"
