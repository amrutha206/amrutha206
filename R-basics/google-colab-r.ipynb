# %% [markdown]
# <a href="https://colab.research.google.com/github/amrutha206/amrutha206/blob/main/R-basics/google-colab-r.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
marks <- c(45,55,65,60,62)
hist(marks)
# Out:
# Plot with title “Histogram of marks”
